# %%
# %%capture
import pandas as pd, os, nltk, tensorflow as tf
from nltk.corpus import stopwords
import numpy as np
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from nltk.corpus import words
nltk.download('stopwords')
nltk.download('words')
nltk.download('punkt_tab')

# !pip install gradio
# !pip install sentence_transformers
# !pip install vaderSentiment
# !pip install langdetect

# %%
# Setup logging

import logging

logging.basicConfig(filename='app.log', level=logging.INFO, format='%(asctime)s - %(message)s')

# %% [markdown]
# ### **Prepare Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_folder = '/content/drive/MyDrive/'
googlie_review = os.path.join(base_folder, 'NPS_reviews_on_Tab_2023.xlsm')
nps_review = os.path.join(base_folder, 'Google_reviews_data_2023.xlsm')

# %%
_googlie_review = pd.read_excel(googlie_review)
_nps_review = pd.read_excel(nps_review)

# %%
_googlie_review.head()
# Out:
#         Date  Rating  Store Id                                 Remarks  \
# 0 2023-12-31    6.25      4001                                    fine
# 1 2023-12-31    5.00      4001                                     noo
# 2 2023-12-31    6.00      4001  well done happy new year do sale offer
# 3 2023-12-31    6.25      4035                                   good
# 4 2023-12-30    5.75      1128                               excellent
#
#            Name       Contact  Sentiment: Positive(0)/Negative(1)/Neutral(2)
# 0    Simran Naz  3.046542e+09                                              2
# 1        munaza  3.025506e+09                                              1
# 2  Fahad sheikh  3.218488e+09                                              0
# 3  Ayesha khald  3.217313e+09                                              0
# 4        Rawish  3.349101e+09                                              0

# %%
_nps_review.head()
# Out:
#                   Date  Store Code               City  Rating  \
# 0  2023-12-30 00:00:00      1041.0  Wapda Town Lahore     5.0
# 1  2023-12-29 00:00:00      1145.0      Stylo MM Alam     4.0
# 2  2023-12-29 00:00:00      1201.0         Rawalpindi     5.0
# 3  2023-12-28 00:00:00      1235.0             Lahore     3.0
# 4  2023-12-28 00:00:00      1022.0            Sahiwal     4.0
#
#                                             Comments  \
# 0                             Very cooperative staff
# 1                     Nice shoes for ladies and kids
# 2                                               Nice
# 3  The prices ar little bit high for a mediocre p...
# 4                    All type of shoes are available
#
#                    Review Reply Reply Date         Customer Name  \
# 0  Thank you for your feedback. 2024-07-19          Ahmad hassan
# 1  Thank you for your feedback. 2024-07-19  Saqib Saqlain (LIFE)
# 2    Thank you for your rating. 2024-07-19        MS Corporation
# 3  Thank you for your feedback. 2024-07-19           Abdul Basit
# 4  Thank you for your feedback. 2024-07-19         SHAFQAT ABBAS
#
#    Sentiment: Positive(0)/Negative(1)/Neutral(2)
# 0                                            0.0
# 1                                            0.0
# 2                                            0.0
# 3                                            2.0
# 4                                            0.0

# %%
new_google = _googlie_review[['Rating', 'Remarks']]
new_nps = _nps_review[['Rating', 'Comments']]

new_google.rename(columns={'Remarks': 'reviews'}, inplace=True)
new_nps.rename(columns={'Comments': 'reviews'}, inplace=True)

new_google.head()
# Out:
# <ipython-input-23-ae4a5de338a8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_google.rename(columns={'Remarks': 'reviews'}, inplace=True)
# <ipython-input-23-ae4a5de338a8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_nps.rename(columns={'Comments': 'reviews'}, inplace=True)
#    Rating                                 reviews
# 0    6.25                                    fine
# 1    5.00                                     noo
# 2    6.00  well done happy new year do sale offer
# 3    6.25                                   good
# 4    5.75                               excellent

# %%
new_nps.head()
# Out:
#    Rating                                            reviews
# 0     5.0                             Very cooperative staff
# 1     4.0                     Nice shoes for ladies and kids
# 2     5.0                                               Nice
# 3     3.0  The prices ar little bit high for a mediocre p...
# 4     4.0                    All type of shoes are available

# %%
# Preprocessing: Remove null values, extra spaces, and new lines

def preprocess_reviews(reviews):
    # Remove null or empty reviews
    reviews = [review for review in reviews if isinstance(review, str) and review.strip()]

    # Strip extra spaces and new lines
    reviews = [review.strip().replace("\n", " ").replace("\r", " ") for review in reviews]

    return reviews

# Apply preprocessing to  Google reviews
if 'reviews' in new_google:
    google_reviews = preprocess_reviews(new_google['reviews'])
else:
    raise KeyError("The key 'reviews' does not exist in the input data.")

# Apply preprocessing to  NPS reviews
if 'reviews' in new_nps:
    nps_reviews = preprocess_reviews(new_nps['reviews'])
else:
    raise KeyError("The key 'reviews' does not exist in the input data.")

logging.info("Preprocessing completed. Null and extra spaces removed. Incomplete words kept for now for clarity, will be re-analyzed later.")

# %%
# GOOGLE DATASET CLASSIFICATION


from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from langdetect import detect

# Predefined complaint types
complaint_types = [
     "Fitting","Quality", "Staff Behaviour", "Network", "Bad", "Good", "Ambiance", "Article","Packing","Price","Variety","No stock","Environment", "Cleanliness", "Crowded", "Service"
]


# Initialize SentenceTransformer (for complaint type embeddings)
model = SentenceTransformer('all-MiniLM-L6-v2')

# Step 1: Create embeddings for the complaint types
complaint_embeddings = model.encode(complaint_types)

# Step 2: Perform Sentiment Analysis to identify negative and neutral reviews
analyzer = SentimentIntensityAnalyzer()
negative_reviews = []
negative_review_indices = []
pos_reviews = []
pos_review_indices = []
review_sentiments = []  # List to store sentiment of each review

# Filter reviews based on sentiment scores
for i, review in enumerate(google_reviews):
    score = analyzer.polarity_scores(review)
    if score['compound'] < -0.05:  # Negative reviews (threshold can be adjusted)
        if len(review.split()) > 1 and detect(review) == 'en':
            negative_reviews.append(review)
            negative_review_indices.append(i)
        review_sentiments.append(1)  # Negative sentiment
    elif score['compound'] > 0.05:  # Positive reviews
        if len(review.split()) > 1 and detect(review) == 'en':
            pos_reviews.append(review)
            pos_review_indices.append(i)
        review_sentiments.append(0)  # Positive sentiment
    else:  # Neutral reviews
        review_sentiments.append(2)  # Neutral sentiment

# Step 3: Create embeddings for the reviews
negative_review_embeddings = model.encode(negative_reviews)
pos_review_embeddings = model.encode(pos_reviews)

# Step 4: Compare each review embedding to complaint type embeddings and map to the most similar complaint
def classify_reviews(review_embeddings, reviews):
    mapped_complaints = []
    for review_embedding in review_embeddings:
        # Compute cosine similarity between the review embedding and all complaint embeddings
        similarities = cosine_similarity([review_embedding], complaint_embeddings)

        # Get the index of the highest similarity score
        best_match_index = np.argmax(similarities)

        # Map to the corresponding complaint type
        mapped_complaints.append(complaint_types[best_match_index])

    return mapped_complaints

# Classify negative and positive reviews
negative_mapped_complaints = classify_reviews(negative_review_embeddings, negative_reviews)
neutral_mapped_complaints = classify_reviews(pos_review_embeddings, pos_reviews)

# Output the mapped complaints for each negative review
for i, (review, complaint) in enumerate(zip(negative_reviews, negative_mapped_complaints)):
    print(f"Review: {google_reviews[negative_review_indices[i]]}")
    print(f"Sentiment: Negative")
    print(f"Mapped Classification: {complaint}")
    print()

# Output the mapped complaints for each positive review
for i, (review, complaint) in enumerate(zip(pos_reviews, neutral_mapped_complaints)):
    print(f"Review: {google_reviews[pos_review_indices[i]]}")
    print(f"Sentiment: Positive")
    print(f"Mapped Classification: {complaint}")
    print()

# Print the list of sentiments for all reviews
# print("Sentiments for all reviews:", review_sentiments)

logging.info('Used all_mini_L6_v2 for embeddings')
logging.info('positives and negatives both analyzed')
logging.info('putting incorrect words into neutral and leaving them out')
# Out:
# Review: quality is not good
# Sentiment: Negative
# Mapped Classification: Quality
#
# Review: whyyyy tf is the 41 size smaller now???????¿?? FIX DAT SHIT please make sure the sizes are good, we pay shit ton of money to buy god shoes and they are small af now. extremely dissatisfied .
# Sentiment: Negative
# Mapped Classification: Fitting
#
# Review: I recently bought 2 shoes and found worst quality ever. I am a regular customer but this time I'm really disappointed and emporium mall branch outlet is not helping at all. one of my shoe broke right after wearing and other one is really uncomfortable. please work on your quality and comfort. Thanks
# Sentiment: Negative
# Mapped Classification: Quality
#
# Review: no net working to check size in another branch no one want to help or call
# Sentiment: Negative
# Mapped Classification: Network
#
# Review: bad not come
# Sentiment: Negative
# Mapped Classification: Bad
#
# Review: very bad quality
# Sentiment: Negative
# Mapped Classification: Quality
#
# Review: yours shoes packing is very unprofessional
# Sentiment: Negative
# Mapped Classification: Packing
#
# Review: your articals are very bad
# Sentiment: Negative
# Mapped Classification: Bad
#
# Review: stitching and finishing very bad
# Sentiment: Negative
# Mapped Classification: Quality
#
# Review: bad service .
# Sentiment: Negative
# Mapped Classification: Service
#
# Review: no new variety.
# Sentiment: Negative
# Mapped Classification: Variety
#
# Review: quality of shoes are not good
# Sentiment: Negative
# Mapped Classification: Quality
#
# Review: got the wrong shoesandhad to comeback
# Sentiment: Negative
# Mapped Classification: Fitting
#
# Review: Good quality
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: Good service and variety.
# Sentiment: Positive
# Mapped Classification: Service
#
# Review: love the shoes and everything
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: enhance the variety for the kids section please
# Sentiment: Positive
# Mapped Classification: Variety
#
# Review: Great Staff.
# Sentiment: Positive
# Mapped Classification: Staff Behaviour
#
# Review: a best gog
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: you have good services
# Sentiment: Positive
# Mapped Classification: Service
#
# Review: the shoes and accessories should be trendy and it's a little paindu as well
# Sentiment: Positive
# Mapped Classification: Variety
#
# Review: servis bohath axhi ha apki
# Sentiment: Positive
# Mapped Classification: Variety
#
# Review: you donot have good service
# Sentiment: Positive
# Mapped Classification: Service
#
# Review: overall great design and helpful staff☺️
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: I like the products
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: need Improvement in collections
# Sentiment: Positive
# Mapped Classification: Packing
#
# Review: good product s
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: this quality is good ad designs are also best
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: try embroidary free designs please
# Sentiment: Positive
# Mapped Classification: No stock
#
# Review: it was a good experience
# Sentiment: Positive
# Mapped Classification: Good
#
# Review: good job lzz sale on clothes these are highly expensive
# Sentiment: Positive
# Mapped Classification: Price
#
# Review: you have a variety of dresses in clothes but it misses woolen shirts for winters. please add a variety of woolen shirts for girls. you can also add small size earrings
# Sentiment: Positive
# Mapped Classification: Variety
#
# Review: I am satisfied for Shopping
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: Good ambiance. Need more designs and heels in bridal wear
# Sentiment: Positive
# Mapped Classification: Ambiance
#
# Review: service socially sales man is very Nice
# Sentiment: Positive
# Mapped Classification: Service
#
# Review: quality should be better
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: A Good experience is all you need.
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: good experience
# Sentiment: Positive
# Mapped Classification: Good
#
# Review: kindly update your stock and change your designer. colour combination scheme is also not good.
# Sentiment: Positive
# Mapped Classification: No stock
#
# Review: it is actually good
# Sentiment: Positive
# Mapped Classification: Good
#
# Review: All is well
# Sentiment: Positive
# Mapped Classification: Good
#
# Review: good quality  of products
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: it was a nice experience,and the staff was really helpful
# Sentiment: Positive
# Mapped Classification: Staff Behaviour
#
# Review: very good service
# Sentiment: Positive
# Mapped Classification: Service
#
# Review: no complain just looking like a wow
# Sentiment: Positive
# Mapped Classification: Quality
#
# Review: the ambientwa nice and the staff is very helpful and the lift does not operate which is the problem for elderly people
# Sentiment: Positive
# Mapped Classification: Staff Behaviour
#
# Review: good serice
# Sentiment: Positive
# Mapped Classification: Good

# %%
import gradio as gr

def classify_new_review(review):
    # Perform sentiment analysis on the input review
    score = analyzer.polarity_scores(review)

    # Check if the review has both positive and negative sentiments
    if score['neg'] > score['pos']:
        sentiment = "Negative"
    elif score['compound'] < -0.05:
        sentiment = "Negative"
    elif -0.05 <= score['compound'] <= 0.05:
        if len(review.split()) >= 1 and detect(review) == 'en':
            sentiment = "Neutral"
        else:
            return "Review is not suitable for classification (too short or not in English)."
    else:
        sentiment = "Positive"

    # Encode the review
    review_embedding = model.encode([review])

    # Compute cosine similarity with complaint type embeddings
    similarities = cosine_similarity(review_embedding, complaint_embeddings)

    # Get the index of the highest similarity score
    best_match_index = np.argmax(similarities)

    # Map to the corresponding complaint type
    complaint_type = complaint_types[best_match_index]

    # Map complaint types to departments
    department_mapping = {
        "Fitting": "Sales Dept",
        "Quality": "Manufacturing Dept",
        "Staff Behaviour": "HR Dept",
        "Network": "IT Dept",
        "Bad": "General Feedback",
        "": "General Feedback",
        "Good": "General Feedback",
        "Ambiance": "Operations Dept",
        "Article": "Sales Dept",
        "Packing": "Logistics Dept",
        "Price": "Sales Dept",
        "Variety": "Merchandising Dept",
        "No stock": "Inventory Dept",
        "Environment": "Facility Management",
        "Cleanliness": "Facility Management",
        "Crowded": "Operations Dept",
        "Service": "Customer Support"
    }

    # Determine the department
    if sentiment == "Negative":
        department = department_mapping.get(complaint_type)
        if department == "General Feedback":
          department = "None (General Feedback)"
    else:
        department = department_mapping.get(complaint_type)
        if department == "General Feedback":
          department = "None (General Feedback)"
        else:
          department = "None (Positive Feedback)"

    return f"Sentiment: {sentiment}\nMapped Classification: {complaint_type}\nDepartment: {department}"

# Gradio interface
interface = gr.Interface(
    fn=classify_new_review,
    inputs=gr.Textbox(label="Enter a Customer Review"),
    outputs=gr.Textbox(label="Classification Result"),
    title="Customer Review Classification",
    description="Enter a customer review to classify it into predefined complaint categories."
)

# Launch the interface
interface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://7f862d2fcf6fc9ae93.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7f862d2fcf6fc9ae93.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# NPS DATA CLASSIFICATION

from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Predefined complaint types
complaint_types = [
     "Fitting","Quality", "Staff Behaviour", "OTP Issue", "Bad", "Good", "Best", "Ambiance", "Article","Packing","Price","Variety","No stock","Environment", "Cleanliness", "Crowded"

]

# Initialize SentenceTransformer (for complaint type embeddings)
model = SentenceTransformer('all-MiniLM-L6-v2')

# Step 1: Create embeddings for the complaint types
complaint_embeddings = model.encode(complaint_types)

# Step 2: Perform Sentiment Analysis to identify negative reviews
analyzer = SentimentIntensityAnalyzer()
negative_reviews = []
negative_review_indices = []
pos_reviews = []
pos_review_indices = []

# Filter only negative reviews based on the sentiment score
for i, review in enumerate(nps_reviews):
    if isinstance(review, str):  # Check if the review is a string
        score = analyzer.polarity_scores(review)
        if score['compound'] < -0.05:  # Negative reviews (threshold can be adjusted)
            negative_reviews.append(review)
            negative_review_indices.append(i)  # Save the index of negative reviews
        elif score['compound'] > 0.06:  # Positive reviews
            pos_reviews.append(review)
            pos_review_indices.append(i)  # Save the index of positive reviews

#_________________________________________________________________
# Step 3: Create embeddings for the negative reviews only
if negative_reviews:  # Check if we have any negative reviews
    negative_review_embeddings = model.encode(negative_reviews)

    # Step 4: Compare each negative review embedding to complaint type embeddings and map to the most similar complaint
    mapped_complaints = []
    for review_embedding in negative_review_embeddings:
        # Compute cosine similarity between the review embedding and all complaint embeddings
        similarities = cosine_similarity([review_embedding], complaint_embeddings)

        # Get the index of the highest similarity score
        best_match_index = np.argmax(similarities)

        # Default to the highest similarity match
        mapped_complaints_for_review = [complaint_types[best_match_index]]

        # Add the mapped complaints for this review
        mapped_complaints.append(mapped_complaints_for_review)

    # Output the mapped complaints for each negative review
    for i, (review, complaints) in enumerate(zip(negative_reviews, mapped_complaints)):
        print(f"Review: {nps_reviews[negative_review_indices[i]]}")  # Display the original review
        print(f"Mapped Issue: {', '.join(complaints)}")
        print(f"Sentiment: Negative")

        print()


#______________________________________________________________
# Step 3: Create embeddings for the positive reviews only
if pos_reviews:  # Check if we have any negative reviews
    pos_review_embeddings = model.encode(negative_reviews)

    # Step 4: Compare each negative review embedding to complaint type embeddings and map to the most similar complaint
    mapped_complaints = []
    for review_embedding in pos_review_embeddings:
        # Compute cosine similarity between the review embedding and all complaint embeddings
        similarities = cosine_similarity([review_embedding], complaint_embeddings)

        # Get the index of the highest similarity score
        best_match_index = np.argmax(similarities)

        # Default to the highest similarity match
        mapped_complaints_for_review = [complaint_types[best_match_index]]

        # Add the mapped complaints for this review
        mapped_complaints.append(mapped_complaints_for_review)

    # Output the mapped complaints for each negative review
    for i, (review, complaints) in enumerate(zip(pos_reviews, mapped_complaints)):
        print(f"Review: {nps_reviews[pos_review_indices[i]]}")  # Display the original review
        print(f"Mapped Classification: {', '.join(complaints)}")
        print(f"Sentiment: Positive")
        print()
# Out:
# Review: I recently had the unfortunate experience of dealing with Stylo Shoes, and I must say it was far from satisfactory. The customer service I encountered was nothing short of a nightmare. From unhelpful representatives to a lack of responsiveness, my interaction with Stylo Shoes has left me with a sour taste. When reaching out for assistance regarding a purchase issue, I encountered a disinterested and uncooperative customer service team. Instead of addressing my concerns promptly, they seemed indifferent to my problems, providing vague responses that left me feeling frustrated and undervalued as a customer. This experience has made me to never shop from Stylo Shoes again. In a market saturated with options, the importance of exceptional customer service cannot be overstated. Unfortunately, Stylo Shoes falls short in this aspect, and as a result, they have lost a once-loyal customer.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Most pathetic experience ever. They have no respect for customers. For them their personal talks are more important than customer standing there. They don't bother even after you highlight the issue. Can't recommend to anyone else. Worst sales staff.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: I like it's item,but not have best designs,and veriety,sale items are so rufe and bad quality
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: No variety.
# Mapped Issue: Variety
# Sentiment: Negative
#
# Review: Prices have gone up too much no value for money
# Mapped Issue: Price
# Sentiment: Negative
#
# Review: Very poor quality products i ll rate 2/10
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: the male staff are literal harassers
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: To bad experience local shoes better than stylo
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Most costly
# Mapped Issue: Price
# Sentiment: Negative
#
# Review: Not gud one.even their staff is very illmannered they have no sense how to deal with customer bad experience.bad staff
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Ever green brand of female foot wear but with pathetic environment in rushy days.
# Mapped Issue: Environment
# Sentiment: Negative
#
# Review: There are very dirty people. Very poor quality and design. They consider it an insult to answer the call. You will never find the person who has a mobile phone in the shop, if there is any problem, they just talk about it. It is better that you go to the president's branch.
# Mapped Issue: Cleanliness
# Sentiment: Negative
#
# Review: Poor customer service, they seem helpless.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Very bad.
# Mapped Issue: Bad
# Sentiment: Negative
#
# Review: Most of them are Very rude. So disappointed. That is the problem that when your business is running successfully they become arrogant. Very bad.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Don't go there early as their air conditioners aren't working until an hour or two after opening and the workers aren't very helpful either
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: We went to buy a coat  for my wife yesterday and I was very disappointed to find that they don't have size in any of their stock. Strange
# Mapped Issue: No stock
# Sentiment: Negative
#
# Review: Empty when entered, Just took a stroll and bought a pair of slippers ASAP. Still, workers gave us space to select the product we liked. No extra formalities.
# Mapped Issue: Packing
# Sentiment: Negative
#
# Review: Shoes are not good. Soles are very stiff. Pair ko kata hai
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Bad experience of returning shoes
# Mapped Issue: Bad
# Sentiment: Negative
#
# Review: I will not recommend to anyone.a very baf experience
# Mapped Issue: Best
# Sentiment: Negative
#
# Review: I am very disappointment with the service I received at your store. I recently purchased four pairs of shoes, but unfortunately, one of them seems to be defective. When I went to exchange it, your staff told me to come back another time and that they had never heard of this issue before. However, when I returned, they refused to exchange it and instead asked me to go through a lengthy reclaim process. I was disappointed with how they handled the situation and their lack of customer service skills. As a business, it's important to know how to deal with customers and provide proper assistance. I hope you can address this issue and improve your customer service in the future.  WORST EXPERIENCE EVER
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Very bad experience
# Mapped Issue: Bad
# Sentiment: Negative
#
# Review: Poor quality, with the title of sale, selling scrap
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Bought a crocs for my kid. The rubber was broken within a month , poor quality and high price !
# Mapped Issue: Price
# Sentiment: Negative
#
# Review: Good items but sales persons arent very customer friendly on sale days
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Pathetic customer service, pathetic product finishing, uncomfortable footwear
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Waste of money
# Mapped Issue: Bad
# Sentiment: Negative
#
# Review: It's an overrated place . Numerous designs available on their online store but are not there . Salesmen are amateurish . Limited variety of shoes , bags and imitation jewelry is on display . Items are overpriced . Rating 6/10
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: They are selling local brands bags and saying that it's from stylo. So pathetic
# Mapped Issue: Packing
# Sentiment: Negative
#
# Review: Quality was not very good
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: The sales rep was not supportive, stock was not placed on the shelf properly. wastage of time due to lack of supportive staff
# Mapped Issue: No stock
# Sentiment: Negative
#
# Review: The person working in your branch who is half bald from head. Don't respect customers specially females.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Too bad polices not recommended
# Mapped Issue: Bad
# Sentiment: Negative
#
# Review: this is a store having shoes of all age from women's children's elders at a very low price sometime there is a sale of 90% you can get all type of shoes socks at a very cheap price there is no issue of car parking and there is also a wheelchair entrance the timing of the store is 11:00 a.m. to 11:00 p.m. whole story central air condition so there is no feeling of summer. there are a very huge variety of shoes sandals chappals.
# Mapped Issue: Price
# Sentiment: Negative
#
# Review: Bad
# Mapped Issue: Bad
# Sentiment: Negative
#
# Review: There are many bad items in the sale.
# Mapped Issue: Bad
# Sentiment: Negative
#
# Review: Very pathetic behaviour of staff, they do not have proper information regarding their products and prices. Very less variety and mostly sizes of shoes are not available...
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Very very unprofessional, rude and disrespectful staff. They don't know how to deal with women or whats the respect of women. They tried to touch every women
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Much expensive  low quality
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Extremely disappointing. ill mannered staff. There behaviour is so rude. No one can buy your shoes with this unprofessional and rude behaviour first teach them how to treat customers! I will never visit this store again and will not recommend anyone to visit this pathetic store.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Finally I said goodbye to stylo. It has been my favourite outlet for shoes over the years but now, many times shoes broke in the middle of the way. Yesterday, I wore a shoes second time and it break and I was in office. It was so embarrassing and it shattered all my confidence entries day. I'll not purchase anything any longer from my once favourite Stylo.
# Mapped Issue: Best
# Sentiment: Negative
#
# Review: They have to update their store. Their many articles were missing which I found in their Islamabad regional outlets.
# Mapped Issue: Article
# Sentiment: Negative
#
# Review: I bought shoes goft for my aunt which was biggest ( one extra for aunt ) in size and the person told me that I can replace it from anywhere. My aunt went to exchange it from the another branch and they said it has no less size manufactured. Brand consistency hecked up!!
# Mapped Issue: Packing
# Sentiment: Negative
#
# Review: Very bad experince. Staff is not coperative and quailty of shoes are very bad
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: 1. Staff not cooperative during Eid Days. 2. System was down - had to wait a lot due to system error.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Experience was not good.
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: staff behavior was annoying. They were Arrogant.I rated 0 Stars. Because staff member Nasir Ali such an rude nd non sense .
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Happened just after a Month Cheap and poor quality So sad Stylo..
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: limited option for kids
# Mapped Issue: Packing
# Sentiment: Negative
#
# Review: They dont care of costumers. They  only Think of making money no matter if they sell broken shoes you dont get money back  stay away from that stylo store.
# Mapped Issue: Fitting
# Sentiment: Negative
#
# Review: Very bad products and worst quality products and customer service is almost zero
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Gun
# Mapped Issue: Fitting
# Sentiment: Negative
#
# Review: purchased a travel bag on 14th Nov, 2022 that broke on first travel. I paid around 13000 that was not even worth 4000. I wish I had purchased it from waterpump market. I will upload pics soon but honestly their quality is pathetic. Lucky1 admins should take notice
# Mapped Issue: Price
# Sentiment: Negative
#
# Review: Costly variety of shoes
# Mapped Issue: Price
# Sentiment: Negative
#
# Review: Bad bad bad customet service..manager gone  to villageto attend teh wedding.guys don't know how to deal...I order stuff online ..they aren't  ready to exchange.. They sent bad and used stuff online..good style with very bad customer  service...shame
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: (Translated by Google) Stylo fateh garh bas thek hi hai.. Shoes change karwanay gaye jis ne pao me me zaakham diye diye kehtay hain sale item ki exchange policy bhi hai.. Manager was rude and sarial talking tone was not good.. after too much request. they exchange it..  (Original) Stylo fateh garh bas thek hi hai.. Shoes change karwanay gaye jis ne pao me zakahm kar diye thay to kehtay hain sale item ki exchange policy b nahi hai.. Manager was rude and sariyal talking tone was not good.. after too much request they exchange it..
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Way too crowded. And too many salesman. Difficult to move around
# Mapped Issue: Crowded
# Sentiment: Negative
#
# Review: They sell low of products such an outdated products
# Mapped Issue: No stock
# Sentiment: Negative
#
# Review: Limited stock but staff is very cooperative.
# Mapped Issue: No stock
# Sentiment: Negative
#
# Review: Prices are hight but the quality is low, staff is cooperative
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: TERRIBLE EXPERIENCE!! They got 1 star because there is no option for no stars. Got a large bag n handcarry, hardcase. Terrible quality. Sewing came undone within 10 days. Did not even get the chance to pack it. Just put in a few things n noticed the bags sewing was coming undone n I was scared it will tear completely during the journey. Went to their zamazama branch to return. They said that it wud be returned but store policy says to go to place of purchase. When we got to ocean mall branch they said we cant return it. We told them that the people at zamazama said it cud be so they did it. The fact that they lied to us and sold us terrible quality items tho r a brand is very upsetting. Stay away!!
# Mapped Issue: Packing
# Sentiment: Negative
#
# Review: Bad customer service. Bad staff behavior.
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: The most useless shop in Pasarur. Worst quality of customer dealing If you want to buy shoes in Pasarur, buy only from Endeavor
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Not so good
# Mapped Issue: Good
# Sentiment: Negative
#
# Review: (Translated by Google) Boring. The products left over from Pakistan are kept in Stylo Kohat.  (Original) Boring. Poray Pakistan se bachi hui products Stylo Kohat mein rakh dee jati hain
# Mapped Issue: Variety
# Sentiment: Negative
#
# Review: Fake offer sharing. Too high price and bad  product quality
# Mapped Issue: Price
# Sentiment: Negative
#
# Review: They dont have the stock waste of time..
# Mapped Issue: No stock
# Sentiment: Negative
#
# Review: Good Stuff, with very Poor Staff behavior and service
# Mapped Issue: Staff Behaviour
# Sentiment: Negative
#
# Review: Although footwear variety is fantastic & in reasonable price. But sitting sofa were so dirty.
# Mapped Issue: Cleanliness
# Sentiment: Negative
#
# Review: Poor quality and very bad consumer services
# Mapped Issue: Quality
# Sentiment: Negative
#
# Review: Nice shoes for ladies and kids
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Nice
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: The prices ar little bit high for a mediocre people. The variety is good though....
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: good
# Mapped Classification: Variety
# Sentiment: Positive
#
# Review: Just Ok
# Mapped Classification: Price
# Sentiment: Positive
#
# Review: Had a bad time with Stylo Shoes. The people there didn't help and took forever to reply. When I needed help with something I bought, they acted like they didn't care. It made me feel really upset and like they didn't care about me. Because of this, I won't buy from Stylo Shoes again. There are lots of other places to buy shoes where they treat you better. Customer service is super important, and Stylo Shoes didn't do a good job with it. So, I won't be going back there.
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: I like it, every colour bags with matching shoes
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: What a shoes for ladies! Amazing and the finishing is so up to mark.
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: best foot wear store
# Mapped Classification: Price
# Sentiment: Positive
#
# Review: Stylo is an old and one of the most favorite brands for women's footwear, handbags, and artificial jewelry.
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: seating can be more better... I couldnt find the space to sit and wear my shoes as it was so crowded
# Mapped Classification: Environment
# Sentiment: Positive
#
# Review: Amazing experience
# Mapped Classification: Cleanliness
# Sentiment: Positive
#
# Review: Good place
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Nice shoes for ladies. A lot of variety available.
# Mapped Classification: Bad
# Sentiment: Positive
#
# Review: Good place for ladies shoes, purse etc
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Nice items
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Excellent
# Mapped Classification: No stock
# Sentiment: Positive
#
# Review: Overall experience is good, Stylo shoes are the best brand.
# Mapped Classification: Packing
# Sentiment: Positive
#
# Review: Polite and cooperative staff. I enjoyed my experience there. Though I wanted to buy *peshawari* they didn't have the required size.
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Good store to buy fancy or regular shoes and bags. Designs are nice too.
# Mapped Classification: Bad
# Sentiment: Positive
#
# Review: "An exquisite selection of trendy footwear & accessories! This shop caters brilliantly to diverse tastes, offering stylish options for every occasion. The customer service is impeccable, enhancing the delightful shopping experience. A must-visit for fashion-forward ladies!"
# Mapped Classification: Best
# Sentiment: Positive
#
# Review: Nice place to visite.
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Best designes
# Mapped Classification: Bad
# Sentiment: Positive
#
# Review: Good staff supportive
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Excellent experience with staff and all produts are amazing
# Mapped Classification: Price
# Sentiment: Positive
#
# Review: The employees were very friendly and I wanted to change the size of the shoes after a couple of days and they did so within minutes and no questions asked. Kudos to that!
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Best shop
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Good articles' sizes were out of stock
# Mapped Classification: Bad
# Sentiment: Positive
#
# Review: Ok
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: vip
# Mapped Classification: Packing
# Sentiment: Positive
#
# Review: Sales article is good in condition...staff is very polite and cooperative....they must have Haier at least 2 cashier due to rush hour.
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Very good serves
# Mapped Classification: No stock
# Sentiment: Positive
#
# Review: Good staff behaviour and best verities in reasonable prices because now service is by name only but stylo best its my 3rd visit to this store i feel like and good this time change verity type examples some dresses ladies and ladies bag ladies hair clips hair bands perfumes etc.
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Good
# Mapped Classification: Bad
# Sentiment: Positive
#
# Review: The staff was very cooperative.. although it's not a very big outlet, but they have a good amount of stock, almost all the good designs that are available online
# Mapped Classification: Price
# Sentiment: Positive
#
# Review: Outlet is good but shoes are of mid quality but higher prices.
# Mapped Classification: Bad
# Sentiment: Positive
#
# Review: good
# Mapped Classification: Bad
# Sentiment: Positive
#
# Review: I just love it
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: The stylo shoes provide good products at almost reasonable prices.
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Nice
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Nice and affordable but the quality they have before is not exist now
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: It’s good … It was surprising to find stylo honey
# Mapped Classification: Best
# Sentiment: Positive
#
# Review: Good place for women dresses
# Mapped Classification: Article
# Sentiment: Positive
#
# Review: It is so good
# Mapped Classification: Packing
# Sentiment: Positive
#
# Review: Nice
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: It was an excellent experience, and  the staff is cooperative .
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Best quality products. Like to buy their makeup and other items during discount sale time
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Nice
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: It is always good to shop from stylo shoes.. Staff is very cooperative
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Good place for female shoes
# Mapped Classification: Packing
# Sentiment: Positive
#
# Review: It's good place to buy shoes
# Mapped Classification: Fitting
# Sentiment: Positive
#
# Review: Good
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Good nice variety of shoes specially ladies party ware shoes and sandals.
# Mapped Classification: Fitting
# Sentiment: Positive
#
# Review: Very respective staff Management I impressed.
# Mapped Classification: Price
# Sentiment: Positive
#
# Review: Great selection of food, clothes and bags
# Mapped Classification: Price
# Sentiment: Positive
#
# Review: Stylo is the perfect shoe store for buying stylish and comfortable shoes and sandals specially for weddings and occasions. Highly recommended.
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Available good product available
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: New arrival not available very lazy staf
# Mapped Classification: Crowded
# Sentiment: Positive
#
# Review: Stylo is good having variety in styles. But I suggest it should have Semi style sandals for ladies More and more. Stylo is good at services. I visited today after 10 days. I have changed my shoes in style and colour also. The behaviour of the whole staff was very grateful.
# Mapped Classification: No stock
# Sentiment: Positive
#
# Review: Stylo Shoes is a rip-off. The prices are sky high, and the manager is more interested in his phone than in helping customers. I would avoid this store at all costs. Overall, I would not recommend Stylo Shoes to anyone.
# Mapped Classification: No stock
# Sentiment: Positive
#
# Review: good variety ...reasonable rates
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Although this is a site of the brand for selling of their faulty or expired stock but you want to buy something cheap, it's a good place.
# Mapped Classification: Packing
# Sentiment: Positive
#
# Review: Good shop
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: They have inside Namaz arrangements for there sales staff which is good initiative
# Mapped Classification: Quality
# Sentiment: Positive
#
# Review: Such a good shop for everyone for a beautiful collection of all kind of shoes
# Mapped Classification: Good
# Sentiment: Positive
#
# Review: Nice products with good discount offers
# Mapped Classification: Variety
# Sentiment: Positive
#
# Review: the best shoes shos ..i like ot v.much
# Mapped Classification: Price
# Sentiment: Positive
#
# Review: 90% of It is for ladies, decent variety of traditional shoes. Good quality brand.
# Mapped Classification: No stock
# Sentiment: Positive
#
# Review: Good quality of products and exellent dealing with customers
# Mapped Classification: Staff Behaviour
# Sentiment: Positive
#
# Review: Good location Special nice staff Considerate
# Mapped Classification: Cleanliness
# Sentiment: Positive
#
# Review: Highly recommended
# Mapped Classification: Quality
# Sentiment: Positive

# %%
import gradio as gr

def classify_new_review(review):
    # Perform sentiment analysis on the input review
    score = analyzer.polarity_scores(review)

    # Check if the review has both positive and negative sentiments
    if score['neg'] > score['pos']:
        sentiment = "Negative"
    elif score['compound'] < -0.05:
        sentiment = "Negative"
    elif -0.05 <= score['compound'] <= 0.05:
        if len(review.split()) >= 1 and detect(review) == 'en':
            sentiment = "Neutral"
        else:
            return "Review is not suitable for classification (too short or not in English)."
    else:
        sentiment = "Positive"

    # Encode the review
    review_embedding = model.encode([review])

    # Compute cosine similarity with complaint type embeddings
    similarities = cosine_similarity(review_embedding, complaint_embeddings)

    # Get the index of the highest similarity score
    best_match_index = np.argmax(similarities)

    # Map to the corresponding complaint type
    complaint_type = complaint_types[best_match_index]

    # Map complaint types to departments
    department_mapping = {
        "Fitting": "Sales Dept",
        "Quality": "Manufacturing Dept",
        "Staff Behaviour": "HR Dept",
        "Network": "IT Dept",
        "Bad": "General Feedback",
        "": "General Feedback",
        "Good": "General Feedback",
        "Ambiance": "Operations Dept",
        "Article": "Sales Dept",
        "Packing": "Logistics Dept",
        "Price": "Sales Dept",
        "Variety": "Merchandising Dept",
        "No stock": "Inventory Dept",
        "Environment": "Facility Management",
        "Cleanliness": "Facility Management",
        "Crowded": "Operations Dept",
        "Service": "Customer Support"
    }

    # Determine the department
    if sentiment == "Negative" or sentiment == "Neutral":
        department = department_mapping.get(complaint_type)
        if department == "General Feedback":
          department = "None (General Feedback)"
    elif sentiment == "Positive":
        department = department_mapping.get(complaint_type)
        if department == "General Feedback":
          department = "None (General Feedback)"
        else:
          department = "None (Positive Feedback)"


    return f"Sentiment: {sentiment}\nMapped Classification: {complaint_type}\nDepartment: {department}"

# Gradio interface
interface = gr.Interface(
    fn=classify_new_review,
    inputs=gr.Textbox(label="Enter a Customer Review"),
    outputs=gr.Textbox(label="Classification Result"),
    title="Customer Review Classification",
    description="Enter a customer review to classify it into predefined complaint categories."
)

# Launch the interface
interface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://674f4fac44b36abca6.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://674f4fac44b36abca6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
logging.info('gradio interface used')
